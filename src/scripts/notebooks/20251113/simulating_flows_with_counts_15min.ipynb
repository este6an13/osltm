# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../../../..")))

from src.scripts.simulate.v2.simulate_with_counts_15min import simulate_average_station_flows_v2
from src.constants.seed import SEED
# Out:
# <class 'src.repo.v2.stations.models.Station'> <class 'src.repo.v2.counts_15min.models.Counts15Min'> <class 'src.repo.v2.processing.models.ProcessedFile'>

# %%
simulate_average_station_flows_v2(
    station_code="07107",  # U Nacional
    date_type="WD",  # e.g. "WD", "SAT", "HOL"
    date_str="2025-10-16",  # Comparison date
    mode="both",  # "in", "out", or "both"
    dist="poisson",
    seed=SEED,
    end_date="2025-09-29",
)

simulate_average_station_flows_v2(
    station_code="07107",  # U Nacional
    date_type="WD",  # e.g. "WD", "SAT", "HOL"
    date_str="2025-10-16",  # Comparison date
    mode="both",  # "in", "out", or "both"
    dist="nb-local",
    seed=SEED,
    end_date="2025-09-29",
)
# Out:
# 📅 Restricting to date range: beginning → 2025-09-29
# 🧮 IN-dispersion summary: 75 / 77 windows overdispersed (97.4%), 2 Poisson-like
#
# 📈 Performance (IN):
#   MAE: 48.234
#   RMSE: 70.192
#   MAPE: 20.797
#   R²: 0.864
#
# 📈 Performance (OUT):
#   MAE: 55.221
#   RMSE: 100.663
#   MAPE: 20.089
#   R²: 0.870
# 📅 Restricting to date range: beginning → 2025-09-29
# 🧮 IN-dispersion summary: 75 / 77 windows overdispersed (97.4%), 2 Poisson-like
#
# 📈 Performance (IN):
#   MAE: 48.039
#   RMSE: 70.942
#   MAPE: 22.002
#   R²: 0.861
#
# 📈 Performance (OUT):
#   MAE: 55.221
#   RMSE: 100.663
#   MAPE: 20.089
#   R²: 0.870
# d:\dequi\repositories\osltm\src\scripts\simulate\v2\simulate_with_counts_15min.py:104: RuntimeWarning: All-NaN slice encountered
#   r_median = np.nanmedian(r_day, axis=0)

# %%
simulate_average_station_flows_v2(
    station_code="02300",  # Calle 100
    date_type="HO",  # e.g. "WD", "SAT", "HOL"
    date_str="2025-11-03",  # Comparison date
    mode="both",  # "in", "out", or "both"
    dist="poisson",
    seed=SEED,
    end_date="2025-09-29",
)

simulate_average_station_flows_v2(
    station_code="02300",  # Calle 100
    date_type="HO",  # e.g. "WD", "SAT", "HOL"
    date_str="2025-11-03",  # Comparison date
    mode="both",  # "in", "out", or "both"
    dist="nb-local",
    seed=SEED,
    end_date="2025-09-29",
)
# Out:
# 📅 Restricting to date range: beginning → 2025-09-29
# 🧮 IN-dispersion summary: 74 / 77 windows overdispersed (96.1%), 3 Poisson-like
#
# 📈 Performance (IN):
#   MAE: 12.182
#   RMSE: 16.206
#   MAPE: 24.172
#   R²: 0.922
#
# 📈 Performance (OUT):
#   MAE: 18.182
#   RMSE: 24.223
#   MAPE: 21.589
#   R²: 0.867
# 📅 Restricting to date range: beginning → 2025-09-29
# 🧮 IN-dispersion summary: 74 / 77 windows overdispersed (96.1%), 3 Poisson-like
#
# 📈 Performance (IN):
#   MAE: 13.429
#   RMSE: 19.737
#   MAPE: 26.961
#   R²: 0.884
#
# 📈 Performance (OUT):
#   MAE: 18.182
#   RMSE: 24.223
#   MAPE: 21.589
#   R²: 0.867
# d:\dequi\repositories\osltm\src\scripts\simulate\v2\simulate_with_counts_15min.py:104: RuntimeWarning: All-NaN slice encountered
#   r_median = np.nanmedian(r_day, axis=0)

# %%
simulate_average_station_flows_v2(
    station_code="07503",  # San Mateo
    date_type="SA",  # e.g. "WD", "SAT", "HOL"
    date_str="2025-11-01",  # Comparison date
    mode="both",  # "in", "out", or "both"
    dist="poisson",
    seed=SEED,
    end_date="2025-09-29",
)

simulate_average_station_flows_v2(
    station_code="07503",  # San Mateo
    date_type="SA",  # e.g. "WD", "SAT", "HOL"
    date_str="2025-11-01",  # Comparison date
    mode="both",  # "in", "out", or "both"
    dist="nb-local",
    seed=SEED,
    end_date="2025-09-29",
)
# Out:
# 📅 Restricting to date range: beginning → 2025-09-29
# 🧮 IN-dispersion summary: 77 / 77 windows overdispersed (100.0%), 0 Poisson-like
#
# 📈 Performance (IN):
#   MAE: 31.091
#   RMSE: 43.529
#   MAPE: 10.802
#   R²: 0.984
#
# 📈 Performance (OUT):
#   MAE: 47.494
#   RMSE: 62.054
#   MAPE: 23.643
#   R²: 0.904
# 📅 Restricting to date range: beginning → 2025-09-29
# 🧮 IN-dispersion summary: 77 / 77 windows overdispersed (100.0%), 0 Poisson-like
#
# 📈 Performance (IN):
#   MAE: 40.169
#   RMSE: 55.868
#   MAPE: 15.799
#   R²: 0.973
#
# 📈 Performance (OUT):
#   MAE: 47.494
#   RMSE: 62.054
#   MAPE: 23.643
#   R²: 0.904

# %%
simulate_average_station_flows_v2(
    station_code="09104",  # Restrepo
    date_type="WD",  # e.g. "WD", "SAT", "HOL"
    date_str="2025-10-02",  # Comparison date
    mode="both",  # "in", "out", or "both"
    dist="poisson",
    seed=SEED,
    end_date="2025-09-29",
)

simulate_average_station_flows_v2(
    station_code="09104",  # Restrepo
    date_type="WD",  # e.g. "WD", "SAT", "HOL"
    date_str="2025-10-02",  # Comparison date
    mode="both",  # "in", "out", or "both"
    dist="nb-local",
    seed=SEED,
    end_date="2025-09-29",
)
# Out:
# 📅 Restricting to date range: beginning → 2025-09-29
# 🧮 IN-dispersion summary: 77 / 77 windows overdispersed (100.0%), 0 Poisson-like
#
# 📈 Performance (IN):
#   MAE: 17.532
#   RMSE: 24.037
#   MAPE: 19.854
#   R²: 0.913
#
# 📈 Performance (OUT):
#   MAE: 34.312
#   RMSE: 48.750
#   MAPE: 20.571
#   R²: 0.829
# 📅 Restricting to date range: beginning → 2025-09-29
# 🧮 IN-dispersion summary: 77 / 77 windows overdispersed (100.0%), 0 Poisson-like
#
# 📈 Performance (IN):
#   MAE: 22.104
#   RMSE: 31.252
#   MAPE: 23.977
#   R²: 0.853
#
# 📈 Performance (OUT):
#   MAE: 34.312
#   RMSE: 48.750
#   MAPE: 20.571
#   R²: 0.829

# %%
simulate_average_station_flows_v2(
    station_code="02000",  # Portal Norte
    date_type="WD",  # e.g. "WD", "SAT", "HOL"
    date_str="2025-10-16",  # Comparison date
    mode="both",  # "in", "out", or "both"
    dist="poisson",
    seed=SEED,
    end_date="2025-09-29",
)

simulate_average_station_flows_v2(
    station_code="02000",  # Portal Norte
    date_type="WD",  # e.g. "WD", "SAT", "HOL"
    date_str="2025-10-16",  # Comparison date
    mode="both",  # "in", "out", or "both"
    dist="nb-local",
    seed=SEED,
    end_date="2025-09-29",
)
# Out:
# 📅 Restricting to date range: beginning → 2025-09-29
# 🧮 IN-dispersion summary: 76 / 77 windows overdispersed (98.7%), 1 Poisson-like
#
# 📈 Performance (IN):
#   MAE: 69.377
#   RMSE: 100.726
#   MAPE: 10.663
#   R²: 0.980
#
# 📈 Performance (OUT):
#   MAE: 116.870
#   RMSE: 156.843
#   MAPE: 14.872
#   R²: 0.932
# 📅 Restricting to date range: beginning → 2025-09-29
# 🧮 IN-dispersion summary: 76 / 77 windows overdispersed (98.7%), 1 Poisson-like
#
# 📈 Performance (IN):
#   MAE: 93.844
#   RMSE: 135.396
#   MAPE: 16.017
#   R²: 0.963
#
# 📈 Performance (OUT):
#   MAE: 116.870
#   RMSE: 156.843
#   MAPE: 14.872
#   R²: 0.932
# d:\dequi\repositories\osltm\src\scripts\simulate\v2\simulate_with_counts_15min.py:104: RuntimeWarning: All-NaN slice encountered
#   r_median = np.nanmedian(r_day, axis=0)
