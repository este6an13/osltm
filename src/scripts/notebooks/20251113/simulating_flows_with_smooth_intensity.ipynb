# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../../../..")))

from src.scripts.simulate.v2.simulate_with_smooth_intensity import evaluate_intensity_model
# Out:
# <class 'src.repo.v2.stations.models.Station'> <class 'src.repo.v2.counts_15min.models.Counts15Min'> <class 'src.repo.v2.processing.models.ProcessedFile'>

# %%
evaluate_intensity_model(
    station_code="07107",  # U Nacional
    date_type="WD",  # e.g. "WD", "SAT", "HOL"
    comparison_date="2025-10-16",  # Comparison date
    smoothing_factor = 10,
    end_date="2025-09-29",
)
# Out:
# 📅 Restricting to: beginning → 2025-09-29
#
# 📈 Performance (IN):
#   MAE : 50.687
#   RMSE: 78.211
#   MAPE: 19.48%
#   R²  : 0.831
#
# 📈 Performance (OUT):
#   MAE : 68.503
#   RMSE: 124.748
#   MAPE: 25.26%
#   R²  : 0.801

# %%
evaluate_intensity_model(
    station_code="02300",  # Calle 100
    date_type="HO",  # e.g. "WD", "SAT", "HOL"
    comparison_date="2025-11-03",  # Comparison date
    smoothing_factor = 10,
    end_date="2025-09-29",
)
# Out:
# 📅 Restricting to: beginning → 2025-09-29
#
# 📈 Performance (IN):
#   MAE : 13.152
#   RMSE: 18.686
#   MAPE: 30.57%
#   R²  : 0.896
#
# 📈 Performance (OUT):
#   MAE : 17.659
#   RMSE: 23.807
#   MAPE: 36.63%
#   R²  : 0.871

# %%
evaluate_intensity_model(
    station_code="07503",  # San Mateo
    date_type="SA",  # e.g. "WD", "SAT", "HOL"
    comparison_date="2025-11-01",  # Comparison date
    smoothing_factor = 10,
    end_date="2025-09-29",
)
# Out:
# 📅 Restricting to: beginning → 2025-09-29
#
# 📈 Performance (IN):
#   MAE : 40.294
#   RMSE: 64.747
#   MAPE: 13.73%
#   R²  : 0.964
#
# 📈 Performance (OUT):
#   MAE : 54.191
#   RMSE: 70.173
#   MAPE: 24.04%
#   R²  : 0.877

# %%
evaluate_intensity_model(
    station_code="09104",  # Restrepo
    date_type="WD",  # e.g. "WD", "SAT", "HOL"
    comparison_date="2025-10-02",  # Comparison date
    smoothing_factor = 10,
    end_date="2025-09-29",
)
# Out:
# 📅 Restricting to: beginning → 2025-09-29
#
# 📈 Performance (IN):
#   MAE : 17.997
#   RMSE: 24.596
#   MAPE: 24.34%
#   R²  : 0.909
#
# 📈 Performance (OUT):
#   MAE : 30.650
#   RMSE: 44.290
#   MAPE: 20.73%
#   R²  : 0.859

# %%
evaluate_intensity_model(
    station_code="02000",  # Portal Norte
    date_type="WD",  # e.g. "WD", "SAT", "HOL"
    comparison_date="2025-10-16",  # Comparison date
    smoothing_factor = 10,
    end_date="2025-09-29",
)
# Out:
# 📅 Restricting to: beginning → 2025-09-29
#
# 📈 Performance (IN):
#   MAE : 96.991
#   RMSE: 143.166
#   MAPE: 15.55%
#   R²  : 0.959
#
# 📈 Performance (OUT):
#   MAE : 143.068
#   RMSE: 202.687
#   MAPE: 26.21%
#   R²  : 0.887
