# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../../../..")))

from src.scripts.analysis.functional_clustering_time_ranges import (
    get_station_daytype_signatures,
    cluster_stations_by_daytype,
    visualize_clusters_per_date_type,
    flatten_feature_matrix,
    test_clustering_stability_and_quality,
)

from src.constants.seed import SEED

# %%
features_df = get_station_daytype_signatures(lambda_type="in", normalize=True, start_time=630, end_time=730)
feature_mat = flatten_feature_matrix(features_df)

# %%
wd_features = feature_mat[feature_mat["date_type"] == "WD"]

stability_quality_df = test_clustering_stability_and_quality(
    wd_features,
    k_values=[2, 3, 4, 5, 6],
    seeds=[0, 42, 123, 999],
)

display(stability_quality_df)
# Out:
#    n_clusters  mean_ARI  silhouette
# 0           2  0.760711    0.442424
# 1           3  0.840696    0.366408
# 2           4  0.635652    0.320120
# 3           5  0.582363    0.331233
# 4           6  0.650665    0.303405

# %%
wd_features = feature_mat[feature_mat["date_type"] == "SA"]

stability_quality_df = test_clustering_stability_and_quality(
    wd_features,
    k_values=[2, 3, 4, 5, 6],
    seeds=[0, 42, 123, 999],
)

display(stability_quality_df)
# Out:
#    n_clusters  mean_ARI  silhouette
# 0           2  0.947883    0.366512
# 1           3  0.500867    0.286532
# 2           4  0.546929    0.301201
# 3           5  0.456775    0.267546
# 4           6  0.590210    0.296398

# %%
wd_features = feature_mat[feature_mat["date_type"] == "SU"]

stability_quality_df = test_clustering_stability_and_quality(
    wd_features,
    k_values=[2, 3, 4, 5, 6],
    seeds=[0, 42, 123, 999],
)

display(stability_quality_df)
# Out:
#    n_clusters  mean_ARI  silhouette
# 0           2  0.676501    0.259335
# 1           3  0.561740    0.271266
# 2           4  0.449722    0.266900
# 3           5  0.532756    0.233213
# 4           6  0.497778    0.231502

# %%
wd_features = feature_mat[feature_mat["date_type"] == "HO"]

stability_quality_df = test_clustering_stability_and_quality(
    wd_features,
    k_values=[2, 3, 4, 5, 6],
    seeds=[0, 42, 123, 999],
)

display(stability_quality_df)
# Out:
#    n_clusters  mean_ARI  silhouette
# 0           2  0.896240    0.340513
# 1           3  0.915720    0.268345
# 2           4  0.453967    0.240437
# 3           5  0.448509    0.227384
# 4           6  0.517916    0.244648

# %%
# Define how many clusters to use per day type
N_CLUSTERS_BY_TYPE = {
    "WD": 2,   # Weekdays
    "SA": 2,   # Saturdays
    "SU": 2,   # Sundays
    "HO": 2,   # Holidays
}

# Run clustering using the new dictionary
cluster_df, summary_df = cluster_stations_by_daytype(
    features_df,
    n_clusters_by_type=N_CLUSTERS_BY_TYPE,
    seed=SEED,
)

# Visualize PCA per day type
visualize_clusters_per_date_type(cluster_df)

# Example: display each WD cluster’s stations
wd_n_clusters = N_CLUSTERS_BY_TYPE["WD"]

for n in range(wd_n_clusters):
    filtered_df = summary_df[
        (summary_df["date_type"] == "WD") & (summary_df["cluster"] == n)
    ]
    print(f"=== Weekday Cluster {n} (n={len(filtered_df)}) ===")
    display(filtered_df)
# Out:
# === Weekday Cluster 0 (n=59) ===
#      station_id   code                             name date_type  cluster
# 456           1  05100              Banderas P. Central        WD        0
# 457           2  09000                    Cabecera Usme        WD        0
# 458           3  05000                  Portal Américas        WD        0
# 459           4  07000  Portal Sur JFK Coop. Financiera        WD        0
# 460           5  57503             Ampliacion San Mateo        WD        0
# 461           6  07505                        LEON XIII        WD        0
# 462           7  08000                     Portal Tunal        WD        0
# 463           8  09004                      Santa Lucía        WD        0
# 464           9  07503          SAN MATEO - C.C. UNISUR        WD        0
# 465          10  07004                          VENECIA        WD        0
# 466          11  07504                         TERREROS        WD        0
# 467          12  07010                             Bosa        WD        0
# 468          13  09005                          Danubio        WD        0
# 469          14  09100                     Calle 40 Sur        WD        0
# 471          16  07006                General Santander        WD        0
# 472          17  07001                          PERDOMO        WD        0
# 473          18  07008               NQS - Calle 30 Sur        WD        0
# 474          19  07002                         MADELENA        WD        0
# 475          20  05103                         Marsella        WD        0
# 476          21  09001                          Molinos        WD        0
# 477          22  09104                         Restrepo        WD        0
# 479          24  07506                         DESPENSA        WD        0
# 480          25  05107                 Américas - Cr.53        WD        0
# 481          26  05002                           Tintal        WD        0
# 482          27  07007              NQS - Calle 38A Sur        WD        0
# 483          28  07005                         ALQUERIA        WD        0
# 484          29  07113                     SANTA ISABEL        WD        0
# 486          31  07003                        SEVILLANA        WD        0
# 487          32  09002                         Consuelo        WD        0
# 488          33  09101                          Quiroga        WD        0
# 490          35  50003                   Corral Molinos        WD        0
# 491          36  50008             Corral Portal Dorado        WD        0
# 494          39  08002                       Biblioteca        WD        0
# 496          41  09106                           Nariño        WD        0
# 498          43  05005                   Transversal 86        WD        0
# 499          44  08001                  Parque el Tunal        WD        0
# 503          48  04000                Cabecera Calle 80        WD        0
# 505          50  10000               Portal 20 de Julio        WD        0
# 507          52  10002              Av. Primero de Mayo        WD        0
# 508          53  03000                      Portal Suba        WD        0
# 509          54  07110                       PALOQUEMAO        WD        0
# 513          58  10003                    Ciudad Jardín        WD        0
# 517          62  03002                    SUBA - TV- 91        WD        0
# 519          64  10001                      Country Sur        WD        0
# 520          65  06111            Universidades – CityU        WD        0
# 528          73  10010                     San Bernardo        WD        0
# 530          75  03003                       21 ANGELES        WD        0
# 533          78  02502                         Terminal        WD        0
# 534          79  09103                            Olaya        WD        0
# 550          95  09003                          Socorro        WD        0
# 555         100  07111                   NQS - RICAURTE        WD        0
# 556         101  10005                     Bicentenario        WD        0
# 567         112  03001                       LA CAMPIÑA        WD        0
# 571         116  07102                Calle 75 - Zona M        WD        0
# 576         121  07101                       CASTELLANA        WD        0
# 583         128  10008                        San Diego        WD        0
# 598         143  12007                  Zona Industrial        WD        0
# 600         145  12002                 CDS - Carrera 32        WD        0
# 605         158  05001                     Patio Bonito        WD        0
# === Weekday Cluster 1 (n=94) ===
#      station_id   code                                             name  \
# 470          15  09105                                        Río Fucha
# 478          23  07112                                        COMUNEROS
# 485          30  12001                             Carrera 43 - COMAPAN
# 489          34  02304                                Heroes - Gel hada
# 492          37  09107                                           Hortúa
# ..          ...    ...                                              ...
# 603         155  09120                                         Calle 63
# 604         156  09122                                         Calle 72
# 606         159  09124  Temporal Calle 34 - Fondo Nacional de Garantias
# 607         160  09125                                Temporal Calle 57
# 608         161  09126                                   Temporal Marly
#
#     date_type  cluster
# 470        WD        1
# 478        WD        1
# 485        WD        1
# 489        WD        1
# 492        WD        1
# ..        ...      ...
# 603        WD        1
# 604        WD        1
# 606        WD        1
# 607        WD        1
# 608        WD        1
#
# [94 rows x 5 columns]
