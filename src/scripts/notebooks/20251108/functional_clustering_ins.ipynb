# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../../../..")))

from src.scripts.analysis.functional_clustering import (
    get_station_daytype_signatures,
    cluster_stations_by_daytype,
    visualize_clusters_per_date_type,
    hierarchical_station_clustering,
    flatten_feature_matrix,
    test_clustering_stability_and_quality,
)

from src.constants.seed import SEED

# %%
features_df = get_station_daytype_signatures(lambda_type="in", normalize=True)
feature_mat = flatten_feature_matrix(features_df)

# %%
wd_features = feature_mat[feature_mat["date_type"] == "WD"]

stability_quality_df = test_clustering_stability_and_quality(
    wd_features,
    k_values=[2, 3, 4, 5, 6],
    seeds=[0, 42, 123, 999],
)

display(stability_quality_df)
# Out:
#    n_clusters  mean_ARI  silhouette
# 0           2  1.000000    0.401700
# 1           3  0.594588    0.326987
# 2           4  0.481405    0.235208
# 3           5  0.508288    0.259272
# 4           6  0.560615    0.225104

# %%
wd_features = feature_mat[feature_mat["date_type"] == "SA"]

stability_quality_df = test_clustering_stability_and_quality(
    wd_features,
    k_values=[2, 3, 4, 5, 6],
    seeds=[0, 42, 123, 999],
)

display(stability_quality_df)
# Out:
#    n_clusters  mean_ARI  silhouette
# 0           2  0.964427    0.386821
# 1           3  0.959192    0.316778
# 2           4  0.498814    0.313547
# 3           5  0.623780    0.245987
# 4           6  0.604176    0.243185

# %%
wd_features = feature_mat[feature_mat["date_type"] == "SU"]

stability_quality_df = test_clustering_stability_and_quality(
    wd_features,
    k_values=[2, 3, 4, 5, 6],
    seeds=[0, 42, 123, 999],
)

display(stability_quality_df)
# Out:
#    n_clusters  mean_ARI  silhouette
# 0           2  0.493265    0.284992
# 1           3  0.486044    0.176544
# 2           4  0.488828    0.164857
# 3           5  0.712834    0.191144
# 4           6  0.478569    0.169463

# %%
wd_features = feature_mat[feature_mat["date_type"] == "HO"]

stability_quality_df = test_clustering_stability_and_quality(
    wd_features,
    k_values=[2, 3, 4, 5, 6],
    seeds=[0, 42, 123, 999],
)

display(stability_quality_df)
# Out:
#    n_clusters  mean_ARI  silhouette
# 0           2  0.499728    0.291500
# 1           3  0.654547    0.222186
# 2           4  0.737137    0.247730
# 3           5  0.517748    0.204208
# 4           6  0.480688    0.172513

# %%
# Define how many clusters to use per day type
N_CLUSTERS_BY_TYPE = {
    "WD": 3,   # Weekdays
    "SA": 2,   # Saturdays
    "SU": 4,   # Sundays
    "HO": 5,   # Holidays
}

# Run clustering using the new dictionary
cluster_df, summary_df = cluster_stations_by_daytype(
    features_df,
    n_clusters_by_type=N_CLUSTERS_BY_TYPE,
    seed=SEED,
)

# Visualize PCA per day type
visualize_clusters_per_date_type(cluster_df)

# Example: display each WD cluster’s stations
wd_n_clusters = N_CLUSTERS_BY_TYPE["WD"]

for n in range(wd_n_clusters):
    filtered_df = summary_df[
        (summary_df["date_type"] == "WD") & (summary_df["cluster"] == n)
    ]
    print(f"=== Weekday Cluster {n} (n={len(filtered_df)}) ===")
    display(filtered_df)
# Out:
# === Weekday Cluster 0 (n=41) ===
#      station_id   code                                 name date_type  cluster
# 455          10  07004                              VENECIA        WD        0
# 463          18  07008                   NQS - Calle 30 Sur        WD        0
# 465          20  05103                             Marsella        WD        0
# 467          22  09104                             Restrepo        WD        0
# 468          23  07112                            COMUNEROS        WD        0
# 470          25  05107                     Américas - Cr.53        WD        0
# 473          28  07005                             ALQUERIA        WD        0
# 474          29  07113                         SANTA ISABEL        WD        0
# 476          31  07003                            SEVILLANA        WD        0
# 478          33  09101                              Quiroga        WD        0
# 481          37  09107                               Hortúa        WD        0
# 483          39  08002                           Biblioteca        WD        0
# 484          40  06000                      Portal Eldorado        WD        0
# 485          41  09106                               Nariño        WD        0
# 486          42  09108                             Hospital        WD        0
# 493          49  02000             Cabecera Autopista Norte        WD        0
# 501          57  06002                            Normandía        WD        0
# 502          58  10003                        Ciudad Jardín        WD        0
# 507          63  04101                       Minuto de Dios        WD        0
# 511          67  02105                            Calle 142        WD        0
# 517          73  10010                         San Bernardo        WD        0
# 521          77  10004                            Policarpa        WD        0
# 523          79  09103                                Olaya        WD        0
# 529          85  04103                           Las Ferias        WD        0
# 533          89  04004                            La Granja        WD        0
# 536          92  02104                            Calle 146        WD        0
# 549         105  04002                           Carrera 90        WD        0
# 550         106  02101                  Toberin - Foundever        WD        0
# 551         107  02200  Alcalá – Colegio S. Tomás Dominicos        WD        0
# 552         108  06108                    Concejo de Bogotá        WD        0
# 553         109  04105                           Carrera 53        WD        0
# 558         114  02201                                Prado        WD        0
# 562         118  04106                           Carrera 47        WD        0
# 563         119  05102            Av. Américas - Av. Boyacá        WD        0
# 567         123  06001                              Modelia        WD        0
# 571         127  03007                      HUMEDAL CORDOBA        WD        0
# 576         132  03005                    SUBA - AV. BOYACA        WD        0
# 581         137  06100             Av. Rojas – UNISALESIANA        WD        0
# 582         138  02103                              Mazurén        WD        0
# 585         141  02001            Centro Comercial Santa Fe        WD        0
# 588         144  02102                            Calle 161        WD        0
# === Weekday Cluster 1 (n=73) ===
#      station_id   code                                             name  \
# 460          15  09105                                        Río Fucha
# 472          27  07007                              NQS - Calle 38A Sur
# 475          30  12001                             Carrera 43 - COMAPAN
# 479          34  02304                                Heroes - Gel hada
# 482          38  09109                                   Tercer Milenio
# ..          ...    ...                                              ...
# 592         155  09120                                         Calle 63
# 593         156  09122                                         Calle 72
# 594         159  09124  Temporal Calle 34 - Fondo Nacional de Garantias
# 595         160  09125                                Temporal Calle 57
# 596         161  09126                                   Temporal Marly
#
#     date_type  cluster
# 460        WD        1
# 472        WD        1
# 475        WD        1
# 479        WD        1
# 482        WD        1
# ..        ...      ...
# 592        WD        1
# 593        WD        1
# 594        WD        1
# 595        WD        1
# 596        WD        1
#
# [73 rows x 5 columns]
# === Weekday Cluster 2 (n=37) ===
#      station_id   code                             name date_type  cluster
# 446           1  05100              Banderas P. Central        WD        2
# 447           2  09000                    Cabecera Usme        WD        2
# 448           3  05000                  Portal Américas        WD        2
# 449           4  07000  Portal Sur JFK Coop. Financiera        WD        2
# 450           5  57503             Ampliacion San Mateo        WD        2
# 451           6  07505                        LEON XIII        WD        2
# 452           7  08000                     Portal Tunal        WD        2
# 453           8  09004                      Santa Lucía        WD        2
# 454           9  07503          SAN MATEO - C.C. UNISUR        WD        2
# 456          11  07504                         TERREROS        WD        2
# 457          12  07010                             Bosa        WD        2
# 458          13  09005                          Danubio        WD        2
# 459          14  09100                     Calle 40 Sur        WD        2
# 461          16  07006                General Santander        WD        2
# 462          17  07001                          PERDOMO        WD        2
# 464          19  07002                         MADELENA        WD        2
# 466          21  09001                          Molinos        WD        2
# 469          24  07506                         DESPENSA        WD        2
# 471          26  05002                           Tintal        WD        2
# 477          32  09002                         Consuelo        WD        2
# 480          36  50008             Corral Portal Dorado        WD        2
# 487          43  05005                   Transversal 86        WD        2
# 488          44  08001                  Parque el Tunal        WD        2
# 492          48  04000                Cabecera Calle 80        WD        2
# 494          50  10000               Portal 20 de Julio        WD        2
# 496          52  10002              Av. Primero de Mayo        WD        2
# 497          53  03000                      Portal Suba        WD        2
# 506          62  03002                    SUBA - TV- 91        WD        2
# 508          64  10001                      Country Sur        WD        2
# 519          75  03003                       21 ANGELES        WD        2
# 520          76  04100                       Carrera 77        WD        2
# 522          78  02502                         Terminal        WD        2
# 524          80  04003           Avenida Ciudad de Cali        WD        2
# 525          81  04001                         Quirigua        WD        2
# 539          95  09003                          Socorro        WD        2
# 556         112  03001                       LA CAMPIÑA        WD        2
# 578         134  05101                 Mandalay - Cr.73        WD        2

# %%
hierarchical_station_clustering(features_df, date_type="WD")
hierarchical_station_clustering(features_df, date_type="SA")
hierarchical_station_clustering(features_df, date_type="SU")
hierarchical_station_clustering(features_df, date_type="HO")
# Out:
# d:\dequi\repositories\osltm\src\scripts\analysis\functional_clustering.py:377: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(dist, method="average")
# d:\dequi\repositories\osltm\src\scripts\analysis\functional_clustering.py:377: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(dist, method="average")
# d:\dequi\repositories\osltm\src\scripts\analysis\functional_clustering.py:377: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(dist, method="average")
# d:\dequi\repositories\osltm\src\scripts\analysis\functional_clustering.py:377: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(dist, method="average")
#          t_00      t_01      t_02      t_03      t_04      t_05      t_06  \
# 0    0.001332  0.002854  0.005419  0.007891  0.010120  0.010633  0.011931
# 4    0.006539  0.010634  0.013227  0.016920  0.015381  0.017468  0.018320
# 8    0.008972  0.013383  0.015904  0.020448  0.019326  0.021183  0.018868
# 12   0.003656  0.007907  0.011908  0.015313  0.014822  0.016245  0.017951
# 16   0.007837  0.014357  0.015373  0.016262  0.014989  0.015499  0.016529
# ..        ...       ...       ...       ...       ...       ...       ...
# 577  0.004117  0.006235  0.008402  0.011646  0.011614  0.010659  0.011608
# 581  0.000979  0.000979  0.001468  0.003589  0.002936  0.010114  0.010114
# 585  0.002532  0.001601  0.002484  0.003526  0.004463  0.006631  0.011993
# 589  0.001472  0.002842  0.005755  0.006061  0.007385  0.007413  0.010556
# 593  0.001578  0.001578  0.002559  0.003148  0.004891  0.007913  0.012372
#
#          t_07      t_08      t_09  ...      t_70      t_71      t_72  \
# 0    0.013509  0.014444  0.015969  ...  0.001791  0.001572  0.000784
# 4    0.018785  0.019891  0.019823  ...  0.001172  0.001079  0.000493
# 8    0.019399  0.020058  0.020193  ...  0.001468  0.000795  0.000305
# 12   0.018826  0.018396  0.018911  ...  0.001190  0.000786  0.000330
# 16   0.015977  0.016812  0.015264  ...  0.001490  0.000960  0.000877
# ..        ...       ...       ...  ...       ...       ...       ...
# 577  0.011664  0.010368  0.008698  ...  0.006893  0.004206  0.002320
# 581  0.013051  0.010114  0.005220  ...  0.003426  0.002936  0.000979
# 585  0.013699  0.008245  0.006644  ...  0.002715  0.002531  0.002531
# 589  0.011927  0.010600  0.011328  ...  0.002403  0.001186  0.000589
# 593  0.011885  0.013196  0.010087  ...  0.001869  0.001869  0.001869
#
#          t_73      t_74      t_75      t_76  station_id  date_type  cluster
# 0    0.000694  0.000497  0.000527  0.000509           1         HO        1
# 4    0.000375  0.000422  0.000413  0.000422           2         HO        1
# 8    0.000210  0.000235  0.000153  0.000163           3         HO        1
# 12   0.000256  0.000223  0.000225  0.000225           4         HO        1
# 16   0.000877  0.000877  0.000877  0.000877           5         HO        1
# ..        ...       ...       ...       ...         ...        ...      ...
# 577  0.001294  0.000658  0.000658  0.000658         155         HO        2
# 581  0.000979  0.000979  0.000979  0.000979         156         HO        2
# 585  0.002531  0.002531  0.002531  0.002531         159         HO        2
# 589  0.000589  0.000589  0.000589  0.000589         160         HO        2
# 593  0.001869  0.001869  0.001869  0.001869         161         HO        2
#
# [147 rows x 80 columns]
