# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../../../..")))

from src.scripts.simulate.v1.simulate_flows import simulate_station_flows
from src.constants.seed import SEED

# %% [markdown]
# U Nacional (07107), Jueves, 16 de Octubre, 2025

# %%
simulate_station_flows(
    station_code="07107",
    date_str="2025-10-16",
    mode="both",
    seed=SEED,
)

# %% [markdown]
# U Nacional (07107), Lunes Festivo, 13 de Octubre, 2025

# %%
simulate_station_flows(
    station_code="07107",
    date_str="2025-10-13",
    mode="both",
    seed=SEED,
)

# %% [markdown]
# U Nacional (07107), Martes, 10 de Junio, 2025

# %%
simulate_station_flows(
    station_code="07107",
    date_str="2025-06-10",
    mode="both",
    seed=SEED,
)

# %% [markdown]
# U Nacional (07107), Miércoles, 18 de Junio, 2025

# %%
simulate_station_flows(
    station_code="07107",
    date_str="2025-06-18",
    mode="both",
    seed=SEED,
)

# %% [markdown]
# U Nacional (07107), Miércoles, 13 de Agosto (Vacaciones), 2025

# %%
simulate_station_flows(
    station_code="07107",
    date_str="2025-08-13",
    mode="both",
    seed=SEED,
)

# %% [markdown]
# Calle 100 (02300), Martes, 22 de Octubre, 2024

# %%
simulate_station_flows(
    station_code="02300",
    date_str="2024-10-22",
    mode="both",
    seed=SEED,
)

# %% [markdown]
# Calle 100 (02300), Jueves, 16 de Octubre, 2024

# %%
simulate_station_flows(
    station_code="02300",
    date_str="2025-10-16",
    mode="both",
    seed=SEED,
)

# %% [markdown]
# Calle 100 (02300), Lunes (Festivo), 23 de Junio, 2025

# %%
simulate_station_flows(
    station_code="02300",
    date_str="2025-06-23",
    mode="both",
    seed=SEED,
)

# %% [markdown]
# Calle 100 (02300), Domingo, 29 de Junio, 2025

# %%
simulate_station_flows(
    station_code="02300",
    date_str="2025-06-29",
    mode="both",
    seed=SEED,
)

# %% [markdown]
# San Mateo (07503), Jueves, 16 de Octubre, 2025

# %%
simulate_station_flows(
    station_code="07503",
    date_str="2025-10-16",
    mode="both",
    seed=SEED,
)

# %% [markdown]
# Restrepo (09104), Jueves, 16 de Octubre, 2025

# %%
simulate_station_flows(
    station_code="09104",
    date_str="2025-10-16",
    mode="both",
    seed=SEED,
)

# %% [markdown]
# ### Results and Observations
#
# We obtained consistent results with those previously generated in
# `src\scripts\notebooks\20251029\flows_comparison.ipynb`.
#
# At that time, the following were obtained:
#
# - **Station-Specific Patterns**: Different stations exhibit distinct temporal behaviors.
# - **Temporal Similarities**: Recurring weekday behavior. Consistency accross months and days within a month.
# - **Holiday Effects**: Notable differences between holiday and non-holiday days
# - **Year-to-Year Consistency**: For Calle 100, consistency between 2024 and 2025
#
# Now, after migrating the model to the new schema, I obtained essentially the same outcomes — this time analyzing by **date** instead of **week of month**.
# This confirms that the **model migration was both successful and accurate**.
