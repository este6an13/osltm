# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../../../..")))

from src.scripts.simulate.v1.simulate_flows_average import simulate_average_station_flows
from src.constants.seed import SEED
# Out:
# <class 'src.repo.v1.stations.models.Station'> <class 'src.repo.v1.estimates.models.Estimate'> <class 'src.repo.v1.processing.models.ProcessedFile'>

# %%
simulate_average_station_flows(
    station_code="07107",  # U Nacional
    date_type="WD",  # e.g. "WD", "SAT", "HOL"
    date_str="2025-10-16",  # Comparison date
    mode="both",  # "in", "out", or "both"
    dist="poisson",
    seed=SEED,
    end_date="2025-09-29",
)

simulate_average_station_flows(
    station_code="07107",  # U Nacional
    date_type="WD",  # e.g. "WD", "SAT", "HOL"
    date_str="2025-10-16",  # Comparison date
    mode="both",  # "in", "out", or "both"
    dist="nb-local",
    seed=SEED,
    end_date="2025-09-29",
)
# Out:
# 📅 Restricting to date range: beginning → 2025-09-29
#
# 📈 Performance (IN):
#   MAE: 15.831
#   RMSE: 23.194
#   MAPE: 20.653
#   R²: 0.866
#
# 📈 Performance (OUT):
#   MAE: 18.013
#   RMSE: 32.278
#   MAPE: 21.167
#   R²: 0.880
# 📅 Restricting to date range: beginning → 2025-09-29
# 🧮 Dispersion summary: 59 / 77 windows overdispersed (76.6%), 18 / 77 Poisson-like (23.4%)
# 🧮 Dispersion summary: 66 / 77 windows overdispersed (85.7%), 11 / 77 Poisson-like (14.3%)
#
# 📈 Performance (IN):
#   MAE: 22.290
#   RMSE: 36.987
#   MAPE: 24.358
#   R²: 0.660
#
# 📈 Performance (OUT):
#   MAE: 21.628
#   RMSE: 38.621
#   MAPE: 26.330
#   R²: 0.828

# %%
simulate_average_station_flows(
    station_code="02300",  # Calle 100
    date_type="HO",  # e.g. "WD", "SAT", "HOL"
    date_str="2025-11-03",  # Comparison date
    mode="both",  # "in", "out", or "both"
    dist="poisson",
    seed=SEED,
    end_date="2025-09-29",
)

simulate_average_station_flows(
    station_code="02300",  # Calle 100
    date_type="HO",  # e.g. "WD", "SAT", "HOL"
    date_str="2025-11-03",  # Comparison date
    mode="both",  # "in", "out", or "both"
    dist="nb-local",
    seed=SEED,
    end_date="2025-09-29",
)
# Out:
# 📅 Restricting to date range: beginning → 2025-09-29
#
# 📈 Performance (IN):
#   MAE: 4.747
#   RMSE: 6.121
#   MAPE: 26.228
#   R²: 0.898
#
# 📈 Performance (OUT):
#   MAE: 6.840
#   RMSE: 9.304
#   MAPE: 27.972
#   R²: 0.823
# 📅 Restricting to date range: beginning → 2025-09-29
# 🧮 Dispersion summary: 61 / 77 windows overdispersed (79.2%), 16 / 77 Poisson-like (20.8%)
# 🧮 Dispersion summary: 64 / 77 windows overdispersed (83.1%), 13 / 77 Poisson-like (16.9%)
#
# 📈 Performance (IN):
#   MAE: 7.444
#   RMSE: 10.879
#   MAPE: 34.407
#   R²: 0.679
#
# 📈 Performance (OUT):
#   MAE: 9.173
#   RMSE: 13.792
#   MAPE: 27.858
#   R²: 0.612

# %%
simulate_average_station_flows(
    station_code="07503",  # San Mateo
    date_type="SA",  # e.g. "WD", "SAT", "HOL"
    date_str="2025-11-01",  # Comparison date
    mode="both",  # "in", "out", or "both"
    dist="poisson",
    seed=SEED,
    end_date="2025-09-29",
)

simulate_average_station_flows(
    station_code="07503",  # San Mateo
    date_type="SA",  # e.g. "WD", "SAT", "HOL"
    date_str="2025-11-01",  # Comparison date
    mode="both",  # "in", "out", or "both"
    dist="nb-local",
    seed=SEED,
    end_date="2025-09-29",
)
# Out:
# 📅 Restricting to date range: beginning → 2025-09-29
#
# 📈 Performance (IN):
#   MAE: 12.866
#   RMSE: 17.705
#   MAPE: 14.176
#   R²: 0.976
#
# 📈 Performance (OUT):
#   MAE: 16.502
#   RMSE: 22.038
#   MAPE: 26.766
#   R²: 0.891
# 📅 Restricting to date range: beginning → 2025-09-29
# 🧮 Dispersion summary: 73 / 77 windows overdispersed (94.8%), 4 / 77 Poisson-like (5.2%)
# 🧮 Dispersion summary: 76 / 77 windows overdispersed (98.7%), 1 / 77 Poisson-like (1.3%)
#
# 📈 Performance (IN):
#   MAE: 14.935
#   RMSE: 20.899
#   MAPE: 17.258
#   R²: 0.966
#
# 📈 Performance (OUT):
#   MAE: 21.658
#   RMSE: 28.111
#   MAPE: 30.010
#   R²: 0.822

# %%
simulate_average_station_flows(
    station_code="09104",  # Restrepo
    date_type="WD",  # e.g. "WD", "SAT", "HOL"
    date_str="2025-10-02",  # Comparison date
    mode="both",  # "in", "out", or "both"
    dist="poisson",
    seed=SEED,
    end_date="2025-09-29",
)

simulate_average_station_flows(
    station_code="09104",  # Restrepo
    date_type="WD",  # e.g. "WD", "SAT", "HOL"
    date_str="2025-10-02",  # Comparison date
    mode="both",  # "in", "out", or "both"
    dist="nb-local",
    seed=SEED,
    end_date="2025-09-29",
)
# Out:
# 📅 Restricting to date range: beginning → 2025-09-29
#
# 📈 Performance (IN):
#   MAE: 7.299
#   RMSE: 9.702
#   MAPE: 20.045
#   R²: 0.872
#
# 📈 Performance (OUT):
#   MAE: 12.299
#   RMSE: 16.498
#   MAPE: 23.383
#   R²: 0.824
# 📅 Restricting to date range: beginning → 2025-09-29
# 🧮 Dispersion summary: 25 / 77 windows overdispersed (32.5%), 52 / 77 Poisson-like (67.5%)
# 🧮 Dispersion summary: 71 / 77 windows overdispersed (92.2%), 6 / 77 Poisson-like (7.8%)
#
# 📈 Performance (IN):
#   MAE: 7.861
#   RMSE: 10.127
#   MAPE: 25.918
#   R²: 0.861
#
# 📈 Performance (OUT):
#   MAE: 15.013
#   RMSE: 19.555
#   MAPE: 25.838
#   R²: 0.753

# %%
simulate_average_station_flows(
    station_code="02000",  # Portal Norte
    date_type="WD",  # e.g. "WD", "SAT", "HOL"
    date_str="2025-10-16",  # Comparison date
    mode="both",  # "in", "out", or "both"
    dist="poisson",
    seed=SEED,
    end_date="2025-09-29",
)

simulate_average_station_flows(
    station_code="02000",  # Portal Norte
    date_type="WD",  # e.g. "WD", "SAT", "HOL"
    date_str="2025-10-16",  # Comparison date
    mode="both",  # "in", "out", or "both"
    dist="nb-local",
    seed=SEED,
    end_date="2025-09-29",
)
# Out:
# 📅 Restricting to date range: beginning → 2025-09-29
#
# 📈 Performance (IN):
#   MAE: 24.195
#   RMSE: 36.348
#   MAPE: 13.383
#   R²: 0.976
#
# 📈 Performance (OUT):
#   MAE: 41.342
#   RMSE: 58.893
#   MAPE: 15.611
#   R²: 0.914
# 📅 Restricting to date range: beginning → 2025-09-29
# 🧮 Dispersion summary: 76 / 77 windows overdispersed (98.7%), 1 / 77 Poisson-like (1.3%)
# 🧮 Dispersion summary: 77 / 77 windows overdispersed (100.0%), 0 / 77 Poisson-like (0.0%)
#
# 📈 Performance (IN):
#   MAE: 33.961
#   RMSE: 48.229
#   MAPE: 16.410
#   R²: 0.958
#
# 📈 Performance (OUT):
#   MAE: 52.619
#   RMSE: 85.751
#   MAPE: 17.683
#   R²: 0.818
