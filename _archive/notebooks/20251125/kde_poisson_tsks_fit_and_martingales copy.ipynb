# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../../../..")))

from src.scripts.analysis.kde_intensity_estimation import run_kde_intensity_estimation

# %%
run_kde_intensity_estimation("20251104", "07107")

# 07107: U Nacional
# 02300: Calle 100
# 09104: Restrepo
# 07503: San Mateo
# Out:
# 📂 Loading data for 20251104 — Station 07107
#
# ...
# 📊 NEGATIVE BINOMIAL OVERDISPERSION TESTS
# ...
#
# ⚠️ Poisson fitted mean is constant — overdispersion test unavailable.
# ⚠️ Overdispersion test could not be computed (degenerate data).
#
# 📉 Model Comparison (AIC):
#    Poisson AIC: 19480.14
#    NB AIC:      8684.92
# d:\dequi\repositories\osltm\.venv\Lib\site-packages\statsmodels\genmod\families\family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# 📊 Time-Rescaling PIT KS Test: p-value = 0.0000

# %%
run_kde_intensity_estimation("20251104", "07503")
# Out:
# 📂 Loading data for 20251104 — Station 07503
#
# ...
# 📊 NEGATIVE BINOMIAL OVERDISPERSION TESTS
# ...
#
# ⚠️ Poisson fitted mean is constant — overdispersion test unavailable.
# ⚠️ Overdispersion test could not be computed (degenerate data).
#
# 📉 Model Comparison (AIC):
#    Poisson AIC: 48168.10
#    NB AIC:      10561.60
# d:\dequi\repositories\osltm\.venv\Lib\site-packages\statsmodels\genmod\families\family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# 📊 Time-Rescaling PIT KS Test: p-value = 0.0000

# %%
run_kde_intensity_estimation("20251104", "02300")
# Out:
# 📂 Loading data for 20251104 — Station 02300
#
# ...
# 📊 NEGATIVE BINOMIAL OVERDISPERSION TESTS
# ...
#
# ⚠️ Poisson fitted mean is constant — overdispersion test unavailable.
# ⚠️ Overdispersion test could not be computed (degenerate data).
#
# 📉 Model Comparison (AIC):
#    Poisson AIC: 43758.84
#    NB AIC:      10632.64
# d:\dequi\repositories\osltm\.venv\Lib\site-packages\statsmodels\genmod\families\family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# 📊 Time-Rescaling PIT KS Test: p-value = 0.0000

# %%
run_kde_intensity_estimation("20251104", "09104")
# Out:
# 📂 Loading data for 20251104 — Station 09104
#
# ...
# 📊 NEGATIVE BINOMIAL OVERDISPERSION TESTS
# ...
#
# ⚠️ Poisson fitted mean is constant — overdispersion test unavailable.
# ⚠️ Overdispersion test could not be computed (degenerate data).
#
# 📉 Model Comparison (AIC):
#    Poisson AIC: 10416.57
#    NB AIC:      7856.37
# d:\dequi\repositories\osltm\.venv\Lib\site-packages\statsmodels\genmod\families\family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# 📊 Time-Rescaling PIT KS Test: p-value = 0.0000
