# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../../../..")))

from src.scripts.analysis.time_series_clustering import run_time_series_inner_clustering

# %%
run_time_series_inner_clustering("20251104", "07107", 500, 600)

# 07107: U Nacional
# 02300: Calle 100
# 09104: Restrepo
# 07503: San Mateo
# Out:
# 📂 Loading data for 20251104 — Station 07107
# d:\dequi\repositories\osltm\src\scripts\analysis\time_series_clustering.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_station["timestamp"] = pd.to_datetime(df_station["Fecha_Transaccion"])
# d:\dequi\repositories\osltm\src\scripts\analysis\time_series_clustering.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_station["time_int"] = (
# 🔍 Clustering results for station 07107:
#    • DBSCAN eps     = 60 sec
# ...

# %%
run_time_series_inner_clustering("20251104", "07503", 500, 600)
# Out:
# 📂 Loading data for 20251104 — Station 07503
# d:\dequi\repositories\osltm\src\scripts\analysis\time_series_clustering.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_station["timestamp"] = pd.to_datetime(df_station["Fecha_Transaccion"])
# d:\dequi\repositories\osltm\src\scripts\analysis\time_series_clustering.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_station["time_int"] = (
# 🔍 Clustering results for station 07503:
#    • DBSCAN eps     = 60 sec
# ...

# %%
run_time_series_inner_clustering("20251104", "02300", 500, 600)
# Out:
# 📂 Loading data for 20251104 — Station 02300
#
# 🔍 Clustering results for station 02300:
#    • DBSCAN eps     = 60 sec
#    • DBSCAN min_pts = 3
#    • Number of clusters found = 5
#    • Noise points             = 4
#      - Cluster 0: 10 arrivals (2025-11-04 05:06:53 → 2025-11-04 05:09:27)
#      - Cluster 1: 31 arrivals (2025-11-04 05:11:12 → 2025-11-04 05:20:36)
#      - Cluster 2: 4 arrivals (2025-11-04 05:21:53 → 2025-11-04 05:22:22)
#      - Cluster 3: 8 arrivals (2025-11-04 05:24:42 → 2025-11-04 05:25:51)
#      - Cluster 4: 229 arrivals (2025-11-04 05:26:55 → 2025-11-04 06:00:57)
#
# 🧾 First 20 rows with cluster labels:
#                 timestamp  cluster
# 45717 2025-11-04 05:00:50       -1
# 47215 2025-11-04 05:01:55       -1
# 47634 2025-11-04 05:02:14       -1
# 52703 2025-11-04 05:05:30       -1
# 54976 2025-11-04 05:06:53        0
# 55829 2025-11-04 05:07:26        0
# 56319 2025-11-04 05:07:44        0
# 57291 2025-11-04 05:08:17        0
# ...

# %%
run_time_series_inner_clustering("20251104", "09104", 500, 600)
# Out:
# 📂 Loading data for 20251104 — Station 09104
#
# 🔍 Clustering results for station 09104:
#    • DBSCAN eps     = 60 sec
#    • DBSCAN min_pts = 3
#    • Number of clusters found = 1
#    • Noise points             = 0
#      - Cluster 0: 605 arrivals (2025-11-04 05:00:49 → 2025-11-04 06:00:58)
#
# 🧾 First 20 rows with cluster labels:
#                 timestamp  cluster
# 45712 2025-11-04 05:00:49        0
# 45829 2025-11-04 05:00:54        0
# 45851 2025-11-04 05:00:55        0
# 46459 2025-11-04 05:01:22        0
# 46564 2025-11-04 05:01:26        0
# 47031 2025-11-04 05:01:46        0
# 47230 2025-11-04 05:01:55        0
# 47409 2025-11-04 05:02:03        0
# 47804 2025-11-04 05:02:21        0
# 48021 2025-11-04 05:02:30        0
# 48437 2025-11-04 05:02:47        0
# 48682 2025-11-04 05:02:57        0
# 48724 2025-11-04 05:02:58        0
# 49251 2025-11-04 05:03:18        0
# 50419 2025-11-04 05:04:00        0
# 50721 2025-11-04 05:04:12        0
# ...
