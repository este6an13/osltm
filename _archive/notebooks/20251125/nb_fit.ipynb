# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../../../..")))

from src.scripts.analysis.nb_fit import run_nb_fit

# %%
run_nb_fit("20251104", "07107")

# 07107: U Nacional
# 02300: Calle 100
# 09104: Restrepo
# 07503: San Mateo
# Out:
# 📂 Loading data for 20251104 — Station 07107
# Method-of-Moments k = 0.777775
# Bootstrap k mean=0.777162, 95% CI = (0.720762, 0.839259)
# Estimated NB dispersion k = 0.007
#
# 📊 Time-Rescaling PIT KS Test: p-value = 0.4070

# %%
run_nb_fit("20251104", "07503")
# Out:
# 📂 Loading data for 20251104 — Station 07503
# Method-of-Moments k = 1.074611
# Bootstrap k mean=1.069921, 95% CI = (0.991860, 1.143085)
# Estimated NB dispersion k = 0.001
#
# 📊 Time-Rescaling PIT KS Test: p-value = 0.4628

# %%
run_nb_fit("20251104", "02300")
# Out:
# 📂 Loading data for 20251104 — Station 02300
# Method-of-Moments k = 0.957944
# Bootstrap k mean=0.956825, 95% CI = (0.893309, 1.023909)
# Estimated NB dispersion k = 0.005
#
# 📊 Time-Rescaling PIT KS Test: p-value = 0.5994

# %%
run_nb_fit("20251104", "09104")
# Out:
# 📂 Loading data for 20251104 — Station 09104
# Method-of-Moments k = 0.339575
# Bootstrap k mean=0.340876, 95% CI = (0.304771, 0.375228)
# Estimated NB dispersion k = 0.070
#
# 📊 Time-Rescaling PIT KS Test: p-value = 0.4239
